# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/venv/bin/python

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
