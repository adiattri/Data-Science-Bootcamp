# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/venv/bin/python

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
import numpy as np

# %%
import package.math

print(dir(package.math))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add']

# %%
from package.math import add
print(add(2,3))
# Out:
# 5

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
import package.maths
print(dir(package.maths))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'addition', 'subtraction']

# %%
from math import *

# %%
from package.maths import subtraction

subtraction(5,2)
# Out:
# 3
