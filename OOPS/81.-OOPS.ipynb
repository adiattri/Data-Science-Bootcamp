# %%
class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
# Out:
# <__main__.Car object at 0x107e21010>

# %%
### Instance Variable and methods

class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

dog1=Dog("Buddy", 3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x107f2d550>
# Buddy
# 3

# %%
class Dog:

    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says whoof")

dog1=Dog("Buddy", 3)

dog1.bark()
dog2 = Dog("Lucy", 4)

dog2.bark()
# Out:
# Buddy says whoof
# Lucy says whoof

# %%
## Modelling a bank account

class BankAccount:

    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited now balance is {self.balance}")

    def withdraw(self,amount):
        if amount > self.balance:
            print("insufficient funds")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. balance is {self.balance}")

    def get_balance(self):
        print(f"balance is {self.balance}")


account=BankAccount("Krish", 5000)

account.get_balance()

account.deposit(100)

account.get_balance()
# Out:
# balance is 5000
# 100 is deposited now balance is 5100
# balance is 5100
