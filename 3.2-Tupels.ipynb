# %%
##create tuple

empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
mixed_tuple=(1,2.1,"Hello")
mixed_tuple
# Out:
# (1, 2.1, 'Hello')

# %%
numbers=(1,2,3,4,5,6)
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[-1])
# Out:
# 6
