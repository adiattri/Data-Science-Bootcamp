# %%
def add(a,b):
    return a+b

add(2,3)
# Out:
# 5

# %%
add=lambda a,b:a+b

type(add)

print(add(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2 == 0:
        return True

even(24)
# Out:
# True

# %%
even1=lambda num:num%2 == 0

even(12)
# Out:
# True
