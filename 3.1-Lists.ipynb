# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
names=["Krish", "Jack", "Jacob", 1, 2, 3]
print(names)
# Out:
# ['Krish', 'Jack', 'Jacob', 1, 2, 3]

# %%
mixed_List=[1,2,True,3.14,"Aditya"]
print(mixed_List)
# Out:
# [1, 2, True, 3.14, 'Aditya']

# %%
###Accessing list items

fruits=["mango","apple","cherry", "berry"]

print(fruits[1])
print(fruits[2])

print(fruits[-1])

print(fruits[0:])

print(fruits[0:2]) ##2 index is not inclusive
# Out:
# apple
# cherry
# berry
# ['mango', 'apple', 'cherry', 'berry']
# ['mango', 'apple']

# %%
##Modifying List Elements

fruits
# Out:
# ['mango', 'apple', 'cherry', 'berry']

# %%
fruits[1]="Watermelon"
print(fruits)
# Out:
# ['mango', 'Watermelon', 'cherry', 'berry']

# %%
fruits[1:]="Watermelon"
print(fruits)
# Out:
# ['mango', 'W', 'a', 't', 'e', 'r', 'm', 'e', 'l', 'o', 'n']

# %%
fruits=["mango","apple","cherry", "berry"]

fruits.append("orange")
print(fruits)
# Out:
# ['mango', 'apple', 'cherry', 'berry', 'orange']

# %%
fruits.insert(1, "banana")
print(fruits)
# Out:
# ['mango', 'banana', 'apple', 'cherry', 'berry', 'orange']

# %%
fruits.remove("banana")
print(fruits)
# Out:
# ['mango', 'apple', 'cherry', 'berry', 'orange']

# %%
fruits.pop()
print(fruits)
# Out:
# ['mango', 'apple', 'cherry', 'berry']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'berry', 'cherry', 'mango']

# %%
fruits.reverse()
print(fruits)
# Out:
# ['mango', 'cherry', 'berry', 'apple']

# %%
fruits.clear()
print(fruits)
# Out:
# []

# %%
##Slicing List
