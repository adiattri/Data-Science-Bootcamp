# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
### what is the relation between height and weight

###scatter plot

plt.scatter(df['Weight'],df['Height'])

# %%
plt.xlabel("Weight")
plt.ylabel("Height")

plt.scatter(df['Weight'],df['Height'])

# %%
###Correlation

df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
import seaborn as sns

sns.pairplot(df)

# %%
#### independent and dependent features

df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
X=df[['Weight']] ### independent feature should be two dimensional or data frame. It is very important
np.array(X).shape
# Out:
# (23, 1)

# %%
###Dependent feature

y=df['Height'] ###This variable can be in series form or one dimensional array

# %%
###Train Test Split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42) 

X_train.shape
# Out:
# (17, 1)

# %%
##Standardization

from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
###Apply Simpple Linear regression

from sklearn.linear_model import LinearRegression

regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Slope is :" ,regression.coef_)
# Out:
# Slope is : [17.2982057]

# %%
print("Intercept is :" ,regression.intercept_)
# Out:
# Intercept is : 156.47058823529412

# %%
###Plot best fit line training data

plt.scatter(X_train,y_train)
plt.plot(X_train, regression.predict(X_train))

# %%
###Prediction for the test data

y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)

print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.665125886795005
# 10.716374991212605

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_pred)

# %%
print(score)
# Out:
# 0.7360826717981276
