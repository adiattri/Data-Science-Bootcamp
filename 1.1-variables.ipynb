# %%
a=100

# %%
age=32
height=6.1
name="aditya"
is_student=True

print("age: ", age)
print("height: ", height)
print("Name: ", name)
# Out:
# age:  32
# height:  6.1
# Name:  aditya

# %%
print("git hub setup")
# Out:
# git hub setup

# %%
print("git")
# Out:
# git

# %%
first_name="krish"
